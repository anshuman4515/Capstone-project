# %% [markdown]
# <a href="https://colab.research.google.com/github/anshuman4515/Capstone-project/blob/main/data_preprocessing_flats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('/content/flats - flats.csv')
df.sample(5)
# Out:
#                         property_name  \
# 1522  4 BHK Flat in Sector 85 Gurgaon
# 2431  2 BHK Flat in Sector 90 Gurgaon
# 335     3 BHK Flat in Nirvana Country
# 2740  1 BHK Flat in Sector 56 Gurgaon
# 564   3 BHK Flat in Sector 83 Gurgaon
#
#                                                    link  \
# 1522  https://www.99acres.com/4-bhk-bedroom-apartmen...
# 2431  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 335   https://www.99acres.com/3-bhk-bedroom-apartmen...
# 2740  https://www.99acres.com/1-bhk-bedroom-apartmen...
# 564   https://www.99acres.com/3-bhk-bedroom-apartmen...
#
#                         society       price             area  \
# 1522           SS The Leaf3.8 ★   2.1 Crore   ₹ 7,467/sq.ft.
# 2431  Shree Vardhman Flora3.8 ★      80 Lac   ₹ 5,925/sq.ft.
# 335        The Close North4.0 ★     3 Crore  ₹ 11,516/sq.ft.
# 2740    Sobha Smriti Apartments      50 Lac   ₹ 8,333/sq.ft.
# 564     Emaar Palm Gardens4.1 ★  1.73 Crore   ₹ 9,105/sq.ft.
#
# ...

# %%
df.shape
# Out:
# (3028, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3028 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3028 non-null   object
#  1   link             3028 non-null   object
#  2   society          3027 non-null   object
#  3   price            3008 non-null   object
#  4   area             3015 non-null   object
#  5   areaWithType     3009 non-null   object
#  6   bedRoom          3009 non-null   object
#  7   bathroom         3009 non-null   object
#  8   balcony          3009 non-null   object
#  9   additionalRoom   1695 non-null   object
#  10  address          3003 non-null   object
#  11  floorNum         3007 non-null   object
#  12  facing           2128 non-null   object
#  13  agePossession    3008 non-null   object
#  14  nearbyLocations  2914 non-null   object
#  15  description      3009 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# property_name         0
# link                  0
# society               1
# price                20
# area                 13
# areaWithType         19
# bedRoom              19
# bathroom             19
# balcony              19
# additionalRoom     1333
# address              25
# floorNum             21
# facing              900
# agePossession        20
# nearbyLocations     114
# description          19
# furnishDetails      824
# features            433
# rating              351
# property_id          19
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                      property_name  \
# 0     2 BHK Flat in Krishna Colony
# 1        2 BHK Flat in Ashok Vihar
# 2              2 BHK Flat in Sohna
# 3  2 BHK Flat in Sector 61 Gurgaon
# 4  2 BHK Flat in Sector 92 Gurgaon
#
#                                                 link                 society  \
# 0  https://www.99acres.com/2-bhk-bedroom-apartmen...  maa bhagwati residency
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...            Apna Enclave
# 2  https://www.99acres.com/2-bhk-bedroom-apartmen...  Tulsiani Easy in Homes
# 3  https://www.99acres.com/2-bhk-bedroom-apartmen...     Smart World Orchard
# 4  https://www.99acres.com/2-bhk-bedroom-apartmen...        Parkwood Westend
#
#         price             area                            areaWithType  \
# 0      45 Lac   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)
# 1      50 Lac   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)
# ...

# %%
df.drop(columns=['link','property_id'], inplace=True)

# %%
df.rename(columns={'area':'price_per_sqft'},inplace=True)
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df['society'].value_counts()
# Out:
# society
# SS The Leaf3.8 ★                                     73
# Tulip Violet4.3 ★                                    40
# Shapoorji Pallonji Joyville Gurugram4.0 ★            39
# Signature Global Park4.0 ★                           36
# Shree Vardhman Victoria3.8 ★                         35
# Tulip Violet4.2 ★                                    33
# Smart World Gems                                     32
# Smart World Orchard                                  32
# Emaar MGF Emerald Floors Premier3.8 ★                32
# Paras Dews                                           31
# DLF The Ultima4.0 ★                                  31
# DLF Regal Gardens3.9 ★                               30
# M3M Woodshire4.0 ★                                   29
# Shree Vardhman Flora3.8 ★                            29
# Signature Global Solera3.7 ★                         28
# La Vida by Tata Housing                              28
# Godrej Nature Plus                                   27
# ...

# %%
df['price'].value_counts()
# Out:
# price
# 1.25 Crore          79
# 1.1 Crore           61
# 1.4 Crore           60
# 1.2 Crore           59
# 1.5 Crore           59
# 90 Lac              58
# 1.3 Crore           57
# 95 Lac              53
# 2 Crore             51
# 1.75 Crore          47
# 1 Crore             46
# 1.6 Crore           43
# 1.35 Crore          41
# 1.55 Crore          40
# 1.9 Crore           40
# 1.65 Crore          38
# 75 Lac              38
# 1.7 Crore           37
# 1.8 Crore           37
# 80 Lac              36
# 2.2 Crore           34
# 50 Lac              33
# 1.15 Crore          33
# 85 Lac              31
# 1.45 Crore          31
# 1.05 Crore          30
# 40 Lac              29
# 60 Lac              29
# 2.5 Crore           29
# 45 Lac              26
# 2.1 Crore           26
# 65 Lac              25
# 2.35 Crore          23
# 1.85 Crore          23
# 35 Lac              23
# 3 Crore             22
# 70 Lac              21
# 55 Lac              20
# 2.25 Crore          20
# ...

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df.shape
# Out:
# (3028, 18)

# %%
df[df['price'] == 'Price on Request']
# Out:
#                          property_name                         society  \
# 25      5 BHK Flat in Sector 1 Gurgaon       The New People Apartments
# 1645   4 BHK Flat in Sector 50 Gurgaon                     SS Hibiscus
# 1973   1 BHK Flat in Sector 31 Gurgaon            Raheja Atlantis3.8 ★
# 2055   2 BHK Flat in Sector 79 Gurgaon              Supertech Araville
# 2358  2 BHK Flat in Sector 37D Gurgaon                 The Millennia 2
# 2523  2 BHK Flat in Sector 95A Gurgaon                   The Roselia 2
# 2550      3 BHK Flat in Sector-2 Sohna              Supertech Hilltown
# 2641  2 BHK Flat in Sector 95A Gurgaon                   The Roselia 2
# 2960  3 BHK Flat in Sector 104 Gurgaon              Godrej Summit3.7 ★
# 2973         4 BHK Flat in Gwal Pahari          Krrish Provence Estate
# 2974   4 BHK Flat in Sector 95 Gurgaon  Sidhartha NCR One Phase 24.1 ★
#
#                  price price_per_sqft  \
# 25    Price on Request            NaN
# ...

# %%
df = df[df['price'] != 'Price on Request']

# %%
df.head()
# Out:
#                      property_name                 society       price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency      45 Lac
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave      50 Lac
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes      40 Lac
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard  1.47 Crore
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend      70 Lac
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# ...

# %%
def treat_price(x):
    try:
        if len(x) >= 2 and x[1] == 'Lac':
            return round(float(x[0]) / 100, 2)
        else:
            return float(x[0])
    except:
        return None

# %%
df['price'] = df['price'].str.split(' ').apply(treat_price)

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#     price_per_sqft                            areaWithType     bedRoom  \
# 0   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 10,000/sq.ft.     19
# ₹ 8,000/sq.ft.      16
# ₹ 12,500/sq.ft.     16
# ₹ 6,666/sq.ft.      13
# ₹ 5,000/sq.ft.      13
# ₹ 8,333/sq.ft.      12
# ₹ 7,500/sq.ft.      12
# ₹ 6,000/sq.ft.      11
# ₹ 8,461/sq.ft.       9
# ₹ 9,000/sq.ft.       8
# ₹ 7,000/sq.ft.       8
# ₹ 12,000/sq.ft.      8
# ₹ 11,111/sq.ft.      7
# ₹ 6,578/sq.ft.       6
# ₹ 8,888/sq.ft.       6
# ₹ 9,230/sq.ft.       6
# ₹ 8,928/sq.ft.       6
# ₹ 11,500/sq.ft.      6
# ₹ 5,500/sq.ft.       6
# ₹ 7,692/sq.ft.       5
# ₹ 7,142/sq.ft.       5
# ₹ 16,000/sq.ft.      5
# ₹ 6,500/sq.ft.       5
# ₹ 11,428/sq.ft.      5
# ₹ 4,666/sq.ft.       5
# ₹ 4,444/sq.ft.       5
# ₹ 8,108/sq.ft.       5
# ₹ 5,384/sq.ft.       5
# ₹ 5,600/sq.ft.       5
# ₹ 4,615/sq.ft.       5
# ₹ 14,242/sq.ft.      5
# ₹ 7,641/sq.ft.       5
# ₹ 7,407/sq.ft.       5
# ₹ 8,205/sq.ft.       5
# ₹ 8,571/sq.ft.       5
# ₹ 5,556/sq.ft.       5
# ₹ 10,714/sq.ft.      5
# ₹ 7,812/sq.ft.       4
# ₹ 4,854/sq.ft.       4
# ...

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 10,000/sq.ft.     19
# ₹ 8,000/sq.ft.      16
# ₹ 12,500/sq.ft.     16
# ₹ 6,666/sq.ft.      13
# ₹ 5,000/sq.ft.      13
# ₹ 8,333/sq.ft.      12
# ₹ 7,500/sq.ft.      12
# ₹ 6,000/sq.ft.      11
# ₹ 8,461/sq.ft.       9
# ₹ 9,000/sq.ft.       8
# ₹ 7,000/sq.ft.       8
# ₹ 12,000/sq.ft.      8
# ₹ 11,111/sq.ft.      7
# ₹ 6,578/sq.ft.       6
# ₹ 8,888/sq.ft.       6
# ₹ 9,230/sq.ft.       6
# ₹ 8,928/sq.ft.       6
# ₹ 11,500/sq.ft.      6
# ₹ 5,500/sq.ft.       6
# ₹ 7,692/sq.ft.       5
# ₹ 7,142/sq.ft.       5
# ₹ 16,000/sq.ft.      5
# ₹ 6,500/sq.ft.       5
# ₹ 11,428/sq.ft.      5
# ₹ 4,666/sq.ft.       5
# ₹ 4,444/sq.ft.       5
# ₹ 8,108/sq.ft.       5
# ₹ 5,384/sq.ft.       5
# ₹ 5,600/sq.ft.       5
# ₹ 4,615/sq.ft.       5
# ₹ 14,242/sq.ft.      5
# ₹ 7,641/sq.ft.       5
# ₹ 7,407/sq.ft.       5
# ₹ 8,205/sq.ft.       5
# ₹ 8,571/sq.ft.       5
# ₹ 5,556/sq.ft.       5
# ₹ 10,714/sq.ft.      5
# ₹ 7,812/sq.ft.       4
# ₹ 4,854/sq.ft.       4
# ...

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 10,000/sq.ft.     19
# ₹ 8,000/sq.ft.      16
# ₹ 12,500/sq.ft.     16
# ₹ 6,666/sq.ft.      13
# ₹ 5,000/sq.ft.      13
# ₹ 8,333/sq.ft.      12
# ₹ 7,500/sq.ft.      12
# ₹ 6,000/sq.ft.      11
# ₹ 8,461/sq.ft.       9
# ₹ 9,000/sq.ft.       8
# ₹ 7,000/sq.ft.       8
# ₹ 12,000/sq.ft.      8
# ₹ 11,111/sq.ft.      7
# ₹ 6,578/sq.ft.       6
# ₹ 8,888/sq.ft.       6
# ₹ 9,230/sq.ft.       6
# ₹ 8,928/sq.ft.       6
# ₹ 11,500/sq.ft.      6
# ₹ 5,500/sq.ft.       6
# ₹ 7,692/sq.ft.       5
# ₹ 7,142/sq.ft.       5
# ₹ 16,000/sq.ft.      5
# ₹ 6,500/sq.ft.       5
# ₹ 11,428/sq.ft.      5
# ₹ 4,666/sq.ft.       5
# ₹ 4,444/sq.ft.       5
# ₹ 8,108/sq.ft.       5
# ₹ 5,384/sq.ft.       5
# ₹ 5,600/sq.ft.       5
# ₹ 4,615/sq.ft.       5
# ₹ 14,242/sq.ft.      5
# ₹ 7,641/sq.ft.       5
# ₹ 7,407/sq.ft.       5
# ₹ 8,205/sq.ft.       5
# ₹ 8,571/sq.ft.       5
# ₹ 5,556/sq.ft.       5
# ₹ 10,714/sq.ft.      5
# ₹ 7,812/sq.ft.       4
# ₹ 4,854/sq.ft.       4
# ...

# %%
df['price_per_sqft']=='4/sq.ft.'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# 62      False
# ...

# %%
df['price_per_sqft'] = df['price_per_sqft'] = (
    df['price_per_sqft']
    .str.split('/')
    .str.get(0)
    .str.replace('₹','', regex=False)
    .str.replace(',','', regex=False)
    .str.strip()
)

df['price_per_sqft'] = pd.to_numeric(df['price_per_sqft'], errors='coerce')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    price_per_sqft                            areaWithType     bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df['bedRoom'].value_counts()
# Out:
# bedRoom
# 3 Bedrooms    1437
# 2 Bedrooms     944
# 4 Bedrooms     478
# 1 Bedroom      104
# 5 Bedrooms      31
# 6 Bedrooms       3
# bedRoom          1
# Name: count, dtype: int64

# %%
df[df['bedRoom'].isnull()]
# Out:
#                                         property_name  \
# 2850                 2 BHK Flat in Sector 107 Gurgaon
# 2851                  4 BHK Flat in Sector 53 Gurgaon
# 2852                    2 BHK Flat in New Palam Vihar
# 2853                              2 BHK Flat in Sohna
# 2923                 3 BHK Flat in Sector 99A Gurgaon
# 2924               1 BHK Flat in Golf Course Ext Road
# 2925                  2 BHK Flat in Sector 89 Gurgaon
# 2927        4 BHK Flat in C Block Sushant Lok Phase 1
# 2928                  2 BHK Flat in Sector 99 Gurgaon
# 2994                        4 BHK Flat in DLF Phase 4
# 2995                  3 BHK Flat in Sector 9A Gurgaon
# 2996                 3 BHK Flat in Sector 37C Gurgaon
# 2997                       3 BHK Flat in Adarsh Nagar
# 2998                      3 BHK Flat in Rajendra Park
# 2999                  2 BHK Flat in Sector 79 Gurgaon
# 3000                 3 BHK Flat in Sector 37C Gurgaon
# ...

# %%
df = df[~df['bedRoom'].isnull()]

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    price_per_sqft                            areaWithType     bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df['bathroom'].value_counts()
# Out:
# bathroom
# 2 Bathrooms    1044
# 3 Bathrooms     989
# 4 Bathrooms     636
# 5 Bathrooms     169
# 1 Bathroom      112
# 6 Bathrooms      42
# 7 Bathrooms       5
# bathroom          1
# Name: count, dtype: int64

# %%
df['bathroom'].isnull().sum()
# Out:
# (0       False
#  1       False
#  2       False
#  3       False
#  4       False
#  5       False
#  6       False
#  7       False
#  8       False
#  9       False
#  10      False
#  11      False
#  12      False
#  13      False
#  14      False
#  15      False
#  16      False
#  17      False
#  18      False
#  19      False
#  20      False
#  21      False
#  22      False
#  23      False
#  24      False
#  26      False
#  27      False
#  28      False
#  29      False
#  30      False
#  31      False
#  32      False
#  33      False
#  34      False
#  35      False
#  36      False
#  37      False
#  38      False
#  39      False
#  40      False
#  41      False
#  42      False
#  43      False
#  44      False
#  45      False
#  46      False
#  47      False
#  48      False
#  49      False
#  50      False
#  51      False
#  52      False
#  53      False
#  54      False
#  55      False
#  56      False
#  57      False
#  58      False
# ...

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    price_per_sqft                            areaWithType     bedRoom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms
#
#       bathroom      balcony additionalRoom  \
# 0  2 Bathrooms    1 Balcony            NaN
# 1  2 Bathrooms    1 Balcony            NaN
# ...

# %%
df['bathroom'] = pd.to_numeric(
    df['bathroom'].str.split(' ').str.get(0),
    errors='coerce'
)
# Out:
# /tmp/ipykernel_1095/3491363460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bathroom'] = pd.to_numeric(

# %%
df['bedRoom'] = pd.to_numeric(
    df['bedRoom'].str.split(' ').str.get(0),
    errors='coerce'
)
# Out:
# /tmp/ipykernel_1095/258852309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bedRoom'] = pd.to_numeric(

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)      2.0       2.0
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)      2.0       2.0
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)      2.0       2.0
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)      2.0       2.0
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)      2.0       2.0
#
#        balcony additionalRoom                              address  \
# ...

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3.0    974
# 2.0    749
# 1.0    315
# Name: count, dtype: int64

# %%
df['balcony'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['balcony'] = pd.to_numeric(
    df['balcony'].str.split(' ').str.get(0),
    errors='coerce'
)
# Out:
# /tmp/ipykernel_1095/2915569885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balcony'] = pd.to_numeric(

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)      2.0       2.0
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)      2.0       2.0
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)      2.0       2.0
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)      2.0       2.0
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)      2.0       2.0
#
#    balcony additionalRoom                              address  \
# ...

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 3.0    974
# 2.0    749
# 1.0    315
# Name: count, dtype: int64

# %%
df['additionalRoom'].value_counts().shape
# Out:
# (50,)

# %%
df['additionalRoom'].isnull().sum()
# Out:
# np.int64(1305)

# %%
df['additionalRoom'].fillna('not available',inplace=True)
# Out:
# /tmp/ipykernel_1095/1615843200.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['additionalRoom'].fillna('not available',inplace=True)
# /tmp/ipykernel_1095/1615843200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['additionalRoom'].fillna('not available',inplace=True)

# %%
df['additionalRoom'] = df['additionalRoom'].str.lower()
# Out:
# /tmp/ipykernel_1095/4218856625.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['additionalRoom'] = df['additionalRoom'].str.lower()

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)      2.0       2.0
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)      2.0       2.0
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)      2.0       2.0
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)      2.0       2.0
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)      2.0       2.0
#
#    balcony additionalRoom                              address  \
# ...

# %%
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# not available                                    1305
# servant room                                      629
# study room                                        232
# others                                            179
# pooja room                                        132
# study room,servant room                            81
# store room                                         76
# pooja room,servant room                            60
# servant room,others                                52
# servant room,pooja room                            30
# study room,others                                  27
# pooja room,study room,servant room,others          25
# pooja room,study room,servant room                 24
# servant room,store room                            19
# pooja room,study room                              13
# pooja room,study room,servant room,store room      12
# servant room,study room                             8
# ...

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)      2.0       2.0
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)      2.0       2.0
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)      2.0       2.0
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)      2.0       2.0
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)      2.0       2.0
#
#    balcony additionalRoom                              address  \
# ...

# %%
df['floorNum']
# Out:
# 0              4th   of 4 Floors
# 1              1st   of 3 Floors
# 2            12nd   of 14 Floors
# 3              2nd   of 4 Floors
# 4              5th   of 8 Floors
# 5              3rd   of 3 Floors
# 6             5th   of 25 Floors
# 7            14th   of 27 Floors
# 8              2nd   of 3 Floors
# 9            31st   of 40 Floors
# 10             1st   of 4 Floors
# 11            4th   of 13 Floors
# 12            4th   of 15 Floors
# 13            3rd   of 20 Floors
# 14           13rd   of 13 Floors
# 15           25th   of 25 Floors
# 16            Ground of 1 Floors
# 17           Ground of 14 Floors
# 18           11st   of 14 Floors
# 19           12nd   of 13 Floors
# 20             4th   of 4 Floors
# 21           11st   of 22 Floors
# 22             4th   of 4 Floors
# 23           Ground of 14 Floors
# 24           10th   of 25 Floors
# 26             3rd   of 3 Floors
# 27           20th   of 20 Floors
# 28            5th   of 17 Floors
# ...

# %%
df['floorNum'].isnull().sum()
# Out:
# np.int64(2)

# %%
df[df['floorNum'].isnull()]
# Out:
#                                 property_name             society  price  \
# 181   3 BHK Flat in Dwarka Expressway Gurgaon  Experion Heartsong   1.08
# 2767          2 BHK Flat in Sector 78 Gurgaon                 NaN   0.60
#
#       price_per_sqft                        areaWithType  bedRoom  bathroom  \
# 181           6150.0  Built Up area: 1758 (163.32 sq.m.)      3.0       3.0
# 2767          3692.0  Built Up area: 1625 (150.97 sq.m.)      2.0       2.0
#
#       balcony additionalRoom  \
# 181       NaN  not available
# 2767      NaN  not available
#
#                                                 address floorNum facing  \
# 181   604, Tower B-3, 6th Floor,Sector 108, Dwarka E...      NaN    NaN
# 2767       Gurgaon, Sector 78 Gurgaon, Gurgaon, Haryana      NaN    NaN
#
#            agePossession nearbyLocations  \
# 181   Under Construction             NaN
# 2767  Under Construction             NaN
#
# ...

# %%
df['floorNum'] = df['floorNum'].str.split(' ').str.get(0).replace('Ground','0').str.replace('Basement','-1').str.replace('Lower','0').str.extract(r'(\d+)')
# Out:
# /tmp/ipykernel_1095/208426714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['floorNum'] = df['floorNum'].str.split(' ').str.get(0).replace('Ground','0').str.replace('Basement','-1').str.replace('Lower','0').str.extract(r'(\d+)')

# %%
df.head()
# Out:
#                      property_name                 society  price  \
# 0     2 BHK Flat in Krishna Colony  maa bhagwati residency   0.45
# 1        2 BHK Flat in Ashok Vihar            Apna Enclave   0.50
# 2              2 BHK Flat in Sohna  Tulsiani Easy in Homes   0.40
# 3  2 BHK Flat in Sector 61 Gurgaon     Smart World Orchard   1.47
# 4  2 BHK Flat in Sector 92 Gurgaon        Parkwood Westend   0.70
#
#    price_per_sqft                            areaWithType  bedRoom  bathroom  \
# 0          5000.0          Carpet area: 900 (83.61 sq.m.)      2.0       2.0
# 1          7692.0          Carpet area: 650 (60.39 sq.m.)      2.0       2.0
# 2          6722.0          Carpet area: 595 (55.28 sq.m.)      2.0       2.0
# 3         12250.0        Carpet area: 1200 (111.48 sq.m.)      2.0       2.0
# 4          5204.0  Super Built up area 1345(124.95 sq.m.)      2.0       2.0
#
#    balcony additionalRoom                              address floorNum  \
# ...

# %%
df['facing'].value_counts()
# Out:
# facing
# North-East    505
# East          490
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# facing          1
# Name: count, dtype: int64

# %%
df['facing'].isnull().sum()
# Out:
# np.int64(874)

# %%
df['facing'].fillna('NA',inplace=True)
# Out:
# /tmp/ipykernel_1095/3692945726.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['facing'].fillna('NA',inplace=True)
# /tmp/ipykernel_1095/3692945726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['facing'].fillna('NA',inplace=True)

# %%
df['facing'].value_counts()
# Out:
# facing
# NA            874
# North-East    505
# East          490
# North         301
# South         203
# West          183
# North-West    162
# South-East    144
# South-West    135
# facing          1
# Name: count, dtype: int64

# %%
df.insert(loc=4,column='area',value=round((df['price']*10000000)/df['price_per_sqft']))

# %%
df.insert(loc=1,column='property_type',value='flat')

# %%
df.head()
# Out:
#                      property_name property_type                 society  \
# 0     2 BHK Flat in Krishna Colony          flat  maa bhagwati residency
# 1        2 BHK Flat in Ashok Vihar          flat            Apna Enclave
# 2              2 BHK Flat in Sohna          flat  Tulsiani Easy in Homes
# 3  2 BHK Flat in Sector 61 Gurgaon          flat     Smart World Orchard
# 4  2 BHK Flat in Sector 92 Gurgaon          flat        Parkwood Westend
#
#    price  price_per_sqft    area                            areaWithType  \
# 0   0.45          5000.0   900.0          Carpet area: 900 (83.61 sq.m.)
# 1   0.50          7692.0   650.0          Carpet area: 650 (60.39 sq.m.)
# 2   0.40          6722.0   595.0          Carpet area: 595 (55.28 sq.m.)
# 3   1.47         12250.0  1200.0        Carpet area: 1200 (111.48 sq.m.)
# 4   0.70          5204.0  1345.0  Super Built up area 1345(124.95 sq.m.)
#
#    bedRoom  bathroom  balcony additionalRoom  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2998 entries, 0 to 3027
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    2998 non-null   object
#  1   property_type    2998 non-null   object
#  2   society          2997 non-null   object
#  3   price            2996 non-null   float64
#  4   price_per_sqft   2996 non-null   float64
#  5   area             2996 non-null   float64
#  6   areaWithType     2998 non-null   object
#  7   bedRoom          2997 non-null   float64
#  8   bathroom         2997 non-null   float64
#  9   balcony          2038 non-null   float64
#  10  additionalRoom   2998 non-null   object
#  11  address          2992 non-null   object
#  12  floorNum         2995 non-null   object
#  13  facing           2998 non-null   object
#  14  agePossession    2997 non-null   object
#  15  nearbyLocations  2907 non-null   object
# ...

# %%
df.shape
# Out:
# (2998, 20)

# %%
df.to_csv('flats_cleaned.csv',index=False)
